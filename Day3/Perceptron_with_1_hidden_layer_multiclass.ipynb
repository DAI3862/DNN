# %% [markdown]
# # Multiclass with 1 hidden layer

# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-

# %% [markdown]
# ## Import Statements

# %%
###-----------------
### Import Libraries
###-----------------

import os
import sys
sys.path.insert(0, r'G:\My Drive\DNN')
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import datasets
from sklearn.model_selection import train_test_split

import seaborn as sns
from sklearn.metrics import accuracy_score, confusion_matrix, ConfusionMatrixDisplay
 
# from utils.helper import fn_plot_decision_boundary # this function is from helper.py

# %%
# print (fn_plot_decision_boundary.__doc__)

# %% [markdown]
# ## Setup Global Parameters

# %%
###----------------
### Some parameters
###----------------

RANDOM_STATE = 24 # REMEMBER: to remove at the time of promotion to production
np.random.seed(RANDOM_STATE)
rng = np.random.default_rng(seed = RANDOM_STATE) # Set Random Seed for reproducible  results

NOISE = 0.2
EPOCHS = 10000  # number of epochs
ALPHA = 0.1  # learning rate
N_SAMPLES = 1000
TEST_SIZE = 0.2

# parameters for Matplotlib
params = {'legend.fontsize': 'medium',
          'figure.figsize': (15, 8),
          'axes.labelsize': 'large',
          'axes.titlesize':'large',
          'xtick.labelsize':'large',
          'ytick.labelsize':'large'
         }

plt.rcParams.update(params)

CMAP = plt.cm.coolwarm
plt.style.use('seaborn-v0_8-darkgrid') # plt.style.use('ggplot')

# %% [markdown]
# ## Generate Data Set
# <div style="font-family: Arial; font-size:1.2em;">
# Sklearn's dataset generator is good source of data for learning. To keep the example simple, I'll suggest  <a href="http://scikit-learn.org/stable/modules/generated/sklearn.datasets.make_moons.html">make_moon</a> dataset generator.
# </div>

# %%
X, y = datasets.make_moons(n_samples=N_SAMPLES, 
                           shuffle=True, 
                           noise=NOISE, 
                           random_state=RANDOM_STATE)
X[:5], y[:5]
# Out:
# (array([[ 0.90633951,  0.90267624],
#         [-1.11536828,  0.75579289],
#         [ 1.88769158,  0.4175967 ],
#         [-0.93345034, -0.02299851],
#         [-0.96872877,  0.06396285]]),
#  array([0, 0, 1, 0, 0], dtype=int64))

# %% [markdown]
# ## Visualization
# <p style="font-family: Arial; font-size:1.2em">
# DataFrames are easier to visualize
# </p>

# %%
data_df = pd.DataFrame(X, columns = ['A', 'B'])

data_df['target'] = y

data_df.head()
# Out:
#           A         B  target
# 0  0.906340  0.902676       0
# 1 -1.115368  0.755793       0
# 2  1.887692  0.417597       1
# 3 -0.933450 -0.022999       0
# 4 -0.968729  0.063963       0

# %%
data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       1000 non-null   float64
#  1   B       1000 non-null   float64
#  2   target  1000 non-null   int64
# dtypes: float64(2), int64(1)
# memory usage: 23.6 KB

# %%
data_df.describe() # Generate descriptive statistic
# Out:
#                  A            B      target
# count  1000.000000  1000.000000  1000.00000
# mean      0.490841     0.239025     0.50000
# std       0.898951     0.540082     0.50025
# min      -1.688795    -0.955280     0.00000
# 25%      -0.149565    -0.205090     0.00000
# 50%       0.500100     0.241163     0.50000
# 75%       1.095048     0.680394     1.00000
# max       2.419113     1.612075     1.00000

# %%
# what labels are present?
data_df.target.unique()
# Out:
# array([0, 1], dtype=int64)

# %%
fig, ax = plt.subplots() # Instantiate
    
data_df['target'].value_counts().plot(ax=ax, kind='bar');

# %%
# Using Seaborn
ax = sns.scatterplot(data=data_df, # data from dataframe
                     x='A', y='B',  # X axis and y axis columns
                     palette=sns.color_palette("bright", 2), # color map
                     hue='target'); # Color as per target column

# %%
# data_train, data_test = data_df.to_numpy()[:900], data_df.to_numpy()[900:]

# %%
# data_train.shape, data_test.shape

# %%
# rng.random(data_train.shape[1])

# %%
def fn_softmax(z):
    '''
    Args:
        z : a matrix of z values of shape (m, n_output)
    returns:
        softmax values of z
    '''
    exp_z = np.exp(z)
    return exp_z / np.sum(exp_z, axis=1, keepdims= True) # keepdims = True avoids the python broadcasting which will results the size of m*n_outputs

# %%
t = fn_softmax(np.asarray([[8, 5, 0], [-10, 0, 10]]))
t.sum(axis=1).shape
# Out:
# (2,)

# %%
def fn_activ(x):

    return np.tanh(x)

def fn_activ_prime(x):

    return 1.0 - np.tanh(x)**2

# %%
def predict(model, X_p):

    W1, b1, W2, b2 = model['W1'], model['b1'], model['W2'], model['b2']
    
    ### Forward Propagation

    # Layer 1
    z1 = X_p.dot(W1) + b1 # Aggregation
    a1 = fn_activ(z1) # Activation

    # Layer 2
    z2 = a1.dot(W2) + b2 # Aggregation
    a2 = fn_softmax(z2) # Activation
    
    return np.argmax(a2, axis=1) # pick index of class with highest probability

# %%
def calculate_loss(model, X_l, y_l):
    W1, b1, W2, b2 = model['W1'], model['b1'], model['W2'], model['b2']
    
    m = X_l.shape[0]

    # Layer 1
    z1 = X_l.dot(W1) + b1 # Aggregation
    a1 = fn_activ(z1) # Activation

    # Layer 2
    z2 = a1.dot(W2) + b2 # Aggregation
    a2 = fn_softmax(z2) # Activation
    
    data_loss = -(y_l*np.log(a2) + 
                  (1 - y_l) * np.log(1 - a2)).sum() # Binary

    return data_loss/m

# %%
loss_hist = {}

# %%
def build_model(X_tr, y_tr, nn_hdim, nn_out, alpha=ALPHA ,epochs = EPOCHS):
    '''
    Args:
        X_tr : Training features
        y_tr : Training labels
        nn_hdim : Number of nodes in the hidden layer
        nn_out : Size of output
    '''
    m, nn_input_dim = X_tr.shape
    nn_output_dim = nn_out
    
    # W1 = rng.random((nn_input_dim, nn_hdim), 
    #          dtype = np.float32) / np.sqrt(nn_input_dim)

    # W2 = rng.random((nn_hdim, nn_output_dim), 
    #         dtype = np.float32) / np.sqrt(nn_hdim)
    W1 = np.random.rand(nn_input_dim, nn_hdim) / np.sqrt(nn_input_dim)
    W2 = np.random.rand(nn_hdim, nn_output_dim) / np.sqrt(nn_hdim)

    b1 = np.zeros((1, nn_hdim), dtype= np.float32)

    b2 = np.zeros((1, nn_output_dim), dtype= np.float32)

    curr_loss = 0
    loss, epoch = [], []

    for i in range(0, epochs):
        ### Forward Propagation

        # Layer 1
        z1 = X_tr.dot(W1) + b1
        a1 = fn_activ(z1)

        # Layer 2
        z2 = a1.dot(W2) + b2
        a2 = fn_softmax(z2)
    
        # Back Propagation 
        assert (a2.shape == y_tr.shape), f'check y {a2.shape}/{y_tr.shape}'
        dz2 = a2 - y_tr ## REMEMBER dim of a2 and y to be same

        dW2 = (a1.T).dot(dz2)
        assert(W2.shape == dW2.shape), f'check W2 {W2.shape}/{dW2.shape}'

        db2 = np.sum(dz2, axis= 0 , keepdims = True)
        assert(b2.shape == db2.shape), f'check b2 {b2.shape}/{db2.shape}'

        da1 = dz2.dot(W2.T)
        assert(a1.shape == da1.shape), f'check a1 {a1.shape}/{da1.shape}'

        # Layer1
        dz1 = da1 * fn_activ_prime(z1)
        assert(z1.shape == dz1.shape), f'check z1 {z1.shape}/{dz1.shape}'
    
        dW1 = (X_tr.T).dot(dz1)
        assert(W1.shape == dW1.shape), f'check W1 {W1.shape}/{dW1.shape}'

        db1 = np.sum(dz1, axis= 0 , keepdims = True)
        assert(b1.shape == db1.shape), f'check b1 {b1.shape}/{db1.shape}'


        # Gradient Update
        W1 += -alpha * dW1/m
        b1 += -alpha * db1/m
        W2 += -alpha * dW2/m
        b2 += -alpha * db2/m

        model = {'W1': W1, 'b1' : b1,
                 'W2': W2, 'b2' : b2
                 }
    
        curr_loss = calculate_loss(model, X_tr, y_tr)
        loss.append(curr_loss)
        epoch.append(i)
        if i%100 == 0:
            print(f'After epoch: {i:3d}; loss: {curr_loss: .5f}')

    loss_hist['epoch'] = epoch
    loss_hist['loss'] = loss

    return model

# %%
y.shape
# Out:
# (1000,)

# %%
y = pd.get_dummies(y).to_numpy()
y
# Out:
# array([[ True, False],
#        [ True, False],
#        [False,  True],
#        ...,
#        [ True, False],
#        [False,  True],
#        [ True, False]])

# %%
y.shape
# Out:
# (1000, 2)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y,
                                                    test_size=TEST_SIZE,
                                                    stratify=y,
                                                    random_state=RANDOM_STATE)

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((800, 2), (200, 2), (800, 2), (200, 2))

# %%
# print(y_train.shape)
# y_train = y_train.reshape(-1, 1)
# y_train.shape

# %%
nn_out_dim = 2

model = build_model(X_train, y_train, 4, nn_out_dim)
# Out:
# After epoch:   0; loss:  1.36221
# After epoch: 100; loss:  0.76973
# After epoch: 200; loss:  0.62692
# After epoch: 300; loss:  0.60988
# After epoch: 400; loss:  0.60560
# After epoch: 500; loss:  0.60184
# After epoch: 600; loss:  0.59662
# After epoch: 700; loss:  0.58866
# After epoch: 800; loss:  0.57650
# After epoch: 900; loss:  0.55882
# After epoch: 1000; loss:  0.53547
# After epoch: 1100; loss:  0.50799
# After epoch: 1200; loss:  0.47896
# After epoch: 1300; loss:  0.45062
# After epoch: 1400; loss:  0.42429
# After epoch: 1500; loss:  0.40036
# After epoch: 1600; loss:  0.37860
# After epoch: 1700; loss:  0.35847
# After epoch: 1800; loss:  0.33926
# After epoch: 1900; loss:  0.32030
# After epoch: 2000; loss:  0.30131
# After epoch: 2100; loss:  0.28261
# After epoch: 2200; loss:  0.26496
# After epoch: 2300; loss:  0.24903
# After epoch: 2400; loss:  0.23515
# After epoch: 2500; loss:  0.22329
# After epoch: 2600; loss:  0.21324
# After epoch: 2700; loss:  0.20475
# After epoch: 2800; loss:  0.19755
# After epoch: 2900; loss:  0.19142
# After epoch: 3000; loss:  0.18618
# After epoch: 3100; loss:  0.18167
# After epoch: 3200; loss:  0.17777
# After epoch: 3300; loss:  0.17437
# After epoch: 3400; loss:  0.17140
# After epoch: 3500; loss:  0.16878
# After epoch: 3600; loss:  0.16647
# After epoch: 3700; loss:  0.16441
# After epoch: 3800; loss:  0.16257
# After epoch: 3900; loss:  0.16092
# After epoch: 4000; loss:  0.15943
# After epoch: 4100; loss:  0.15808
# After epoch: 4200; loss:  0.15686
# After epoch: 4300; loss:  0.15574
# After epoch: 4400; loss:  0.15472
# After epoch: 4500; loss:  0.15378
# After epoch: 4600; loss:  0.15291
# After epoch: 4700; loss:  0.15211
# After epoch: 4800; loss:  0.15137
# After epoch: 4900; loss:  0.15068
# After epoch: 5000; loss:  0.15004
# After epoch: 5100; loss:  0.14944
# After epoch: 5200; loss:  0.14887
# After epoch: 5300; loss:  0.14835
# After epoch: 5400; loss:  0.14785
# After epoch: 5500; loss:  0.14738
# After epoch: 5600; loss:  0.14694
# After epoch: 5700; loss:  0.14653
# After epoch: 5800; loss:  0.14613
# After epoch: 5900; loss:  0.14576
# After epoch: 6000; loss:  0.14540
# After epoch: 6100; loss:  0.14507
# After epoch: 6200; loss:  0.14474
# After epoch: 6300; loss:  0.14444
# After epoch: 6400; loss:  0.14414
# After epoch: 6500; loss:  0.14386
# After epoch: 6600; loss:  0.14359
# After epoch: 6700; loss:  0.14334
# After epoch: 6800; loss:  0.14309
# After epoch: 6900; loss:  0.14285
# After epoch: 7000; loss:  0.14262
# After epoch: 7100; loss:  0.14240
# After epoch: 7200; loss:  0.14219
# After epoch: 7300; loss:  0.14199
# After epoch: 7400; loss:  0.14179
# After epoch: 7500; loss:  0.14160
# After epoch: 7600; loss:  0.14142
# After epoch: 7700; loss:  0.14124
# After epoch: 7800; loss:  0.14107
# After epoch: 7900; loss:  0.14090
# After epoch: 8000; loss:  0.14074
# After epoch: 8100; loss:  0.14059
# After epoch: 8200; loss:  0.14044
# After epoch: 8300; loss:  0.14029
# After epoch: 8400; loss:  0.14015
# After epoch: 8500; loss:  0.14001
# After epoch: 8600; loss:  0.13988
# After epoch: 8700; loss:  0.13975
# After epoch: 8800; loss:  0.13962
# After epoch: 8900; loss:  0.13950
# After epoch: 9000; loss:  0.13938
# After epoch: 9100; loss:  0.13926
# After epoch: 9200; loss:  0.13915
# After epoch: 9300; loss:  0.13904
# After epoch: 9400; loss:  0.13893
# After epoch: 9500; loss:  0.13883
# After epoch: 9600; loss:  0.13872
# After epoch: 9700; loss:  0.13862
# After epoch: 9800; loss:  0.13853
# After epoch: 9900; loss:  0.13843

# %%
plt.plot(loss_hist['epoch'], loss_hist['loss'])

# %%
model
# Out:
# {'W1': array([[ 2.59236392,  0.64781309,  2.70594671, -3.25115539],
#         [-1.20154042,  0.79539172,  2.01303509,  1.53530063]]),
#  'b1': array([[-3.3354867, -0.3727139, -1.7698953, -1.827143 ]], dtype=float32),
#  'W2': array([[-3.49564527,  3.75590756],
#         [ 0.23027235,  0.11319467],
#         [ 3.88379121, -3.07889422],
#         [ 3.67908938, -3.28838478]]),
#  'b2': array([[-0.05844026,  0.05844026]], dtype=float32)}

# %%
y_pred = predict(model, X_test)

accuracy_score(np.argmax(y_test, axis =1), y_pred)
# Out:
# 0.985

# %%
accuracy_score()

# %%
cm = confusion_matrix(np.argmax(y_test, axis =1), y_pred)
cm
# Out:
# array([[99,  1],
#        [ 2, 98]], dtype=int64)

# %%
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
    
fig, ax = plt.subplots(figsize = (6,6))

disp.plot(ax = ax, cmap = 'Blues', xticks_rotation = 'vertical', colorbar=False)
# Disable the grid
ax.grid(False)

plt.show();

# %%
X = X_train

fig, ax = plt.subplots()
dm = 0.005 # Smoothen the curve

X_min, X_max = X[:,0].min() - 0.05, X[:,0].max() + 0.05
y_min, y_max = X[:,1].min() - 0.05, X[:,1].max() + 0.05

xx, yy = np.meshgrid(np.arange(X_min, X_max, dm),
                     np.arange(y_min, y_max, dm))

XX = np.c_[xx.ravel(), yy.ravel()]
# XX = np.hstack((XX, np.ones((XX.shape[0],1))))

y_pred = predict(model, XX)

# for row in XX:
#     pred = predict(row, model)
#     y_pred.append(np.round(pred)) # to get only 2 sections in the contour, we used np.round(pred)

Z = np.array(y_pred).reshape(xx.shape)

ax.contourf(xx, yy, Z, cmap=CMAP, alpha=0.8)
ax.scatter(X[:,0], X[:,1], c = y_train.argmax(axis=1),edgecolors='k', cmap=plt.cm.bwr, marker='o');

# %%
xx.shape, yy.shape
# Out:
# ((534, 780), (534, 780))

# %% [markdown]
# Training Accuracy

# %%
predictions = []

for row in data_train:
    
    a = predict(row, weights)
    
    prediction = 0
    
    if a >= 0.5: prediction = 1 # argmax

    predictions.append(prediction)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[44], line 3
#       1 predictions = []
# ----> 3 for row in data_train:
#       5     a = predict(row, weights)
#       7     prediction = 0
#
# NameError: name 'data_train' is not defined

# %%
accuracy_score(data_train[:,-1], predictions)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 accuracy_score(data_train[:,-1], predictions)
#
# NameError: name 'data_train' is not defined

# %% [markdown]
# Testing Accuracy

# %%
predictions = []

for row in data_test:
    
    a = predict(row, weights)
    
    prediction = 0
    
    if a >= 0.5: prediction = 1
    predictions.append(prediction)

accuracy_score(data_test[:,-1], predictions)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[46], line 3
#       1 predictions = []
# ----> 3 for row in data_test:
#       5     a = predict(row, weights)
#       7     prediction = 0
#
# NameError: name 'data_test' is not defined

# %%
cm = confusion_matrix(data_test[:, -1], predictions)
cm
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 cm = confusion_matrix(data_test[:, -1], predictions)
#       2 cm
#
# NameError: name 'data_test' is not defined

# %%
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
    
fig, ax = plt.subplots(figsize = (6,6))

disp.plot(ax = ax, cmap = 'Blues', xticks_rotation = 'vertical', colorbar=False)
# Disable the grid
ax.grid(False)

plt.show();
